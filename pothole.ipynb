# %%
pip install -r requirements.txt
# Out:
# ...
#
# ...
#   Using cached opencv_python-4.5.5.64-cp36-abi3-win_amd64.whl (35.4 MB)
# ...
#   Using cached tensorboard-2.9.0-py3-none-any.whl (5.8 MB)
# ...
#   Using cached thop-0.0.31.post2005241907-py3-none-any.whl (8.7 kB)
# ...
#   Using cached google_auth-2.6.6-py2.py3-none-any.whl (156 kB)
# ...
#   Using cached absl_py-1.0.0-py3-none-any.whl (126 kB)
# ...
#   Using cached tensorboard_data_server-0.6.1-py3-none-any.whl (2.4 kB)
# ...
#   Using cached tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
# ...
#   Using cached google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# ...
#   Using cached Markdown-3.3.7-py3-none-any.whl (97 kB)
# ...
#   Using cached cachetools-5.0.0-py3-none-any.whl (9.1 kB)
# ...
#   Using cached pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
# ...
#   Using cached rsa-4.8-py3-none-any.whl (39 kB)
# ...
#   Using cached requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# ...
#   Using cached pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
# ...
#   Using cached oauthlib-3.2.0-py3-none-any.whl (151 kB)
# ...

# %%
import torch
import utils
display = utils.notebook_init()
# Out:
# YOLOv5  2022-5-7 torch 1.11.0+cpu CPU
# Setup complete  (12 CPUs, 7.3 GB RAM, 6.9/100.0 GB disk)

# %%
# !python train.py --img 640 --batch 15 --epochs 60 --data pot.yaml --weights yolov5s.pt --cache
# Out:
# Command 'git fetch && git config --get remote.origin.url' returned non-zero exit status 1.
# train: weights=yolov5s.pt, cfg=, data=pot.yaml, hyp=data\hyps\hyp.scratch-low.yaml, epochs=60, batch_size=15, imgsz=640, rect=False, resume=False, nosave=False, noval=False, noautoanchor=False, noplots=False, evolve=None, bucket=, cache=ram, image_weights=False, device=, multi_scale=False, single_cls=False, optimizer=SGD, sync_bn=False, workers=8, project=runs\train, name=exp, exist_ok=False, quad=False, cos_lr=False, label_smoothing=0.0, patience=100, freeze=[0], save_period=-1, local_rank=-1, entity=None, upload_dataset=False, bbox_interval=-1, artifact_alias=latest
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
# 'git' is not recognized as an internal or external command,
# operable program or batch file.
# YOLOv5  2022-5-7 torch 1.11.0+cpu CPU
#
# ...
